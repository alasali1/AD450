# %%
import requests
import lxml
import html5lib
import pandas as pd
from bs4 import BeautifulSoup

url = 'https://www.worldometers.info/coronavirus/country/us/#nav-yesterday'
response = requests.get(url)
data = response.text

soup = BeautifulSoup(data, 'html.parser')
table = soup.find(id="usa_table_countries_today")


df = pd.read_html(str(table), flavor='html5lib')[0]

remove = ["#", "Source", "Projections"]

df = df.loc[:, ~df.columns.isin(remove)]
dataframe = df.drop([df.index[0]])

dataframe.head(10)
# Out:
#           USAState  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 1       California     8995321       NaN      86200.0        NaN
# 2            Texas     6642650       NaN      85733.0        NaN
# 3          Florida     5856468       NaN      70789.0        NaN
# 4         New York     5079805       NaN      67967.0        NaN
# 5         Illinois     3035870       NaN      37054.0        NaN
# 6     Pennsylvania     2760617       NaN      43486.0        NaN
# 7             Ohio     2657358       NaN      36822.0        NaN
# 8   North Carolina     2595368       NaN      22725.0        NaN
# 9          Georgia     2469089       NaN      35708.0        NaN
# 10        Michigan     2363519       NaN      34766.0        NaN
#
#     TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop   TotalTests  \
# 1              NaN          NaN          227659.0         2182.0  148205138.0
# 2              NaN          NaN          229089.0         2957.0   60477237.0
# ...

# %%
df.rename
dfcases= dataframe[["USAState", "Tot Cases/1M pop"]]
dfcases.head().sort_values(by=['Tot Cases/1M pop'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <module>
# ----> 1 dfcases= dataframe[["USAState", "Tot Cases/1M pop"]]
#       2 dfcases.head().sort_values(by=['Tot Cases/1M pop'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
dfdeaths= dataframe[["USAState", "TotalDeaths"]]
dfdeaths.head().sort_values(by=['TotalDeaths'])
# Out:
#      USAState  TotalDeaths
# 5    Illinois      37054.0
# 4    New York      67967.0
# 3     Florida      70789.0
# 2       Texas      85733.0
# 1  California      86200.0

# %%
dfdeathspop= dataframe[["USAState", "Deaths/1M pop"]]
dfdeathspop.head().sort_values(by=['Deaths/1M pop'])
# Out:
#      USAState  Deaths/1M pop
# 1  California         2182.0
# 5    Illinois         2924.0
# 2       Texas         2957.0
# 3     Florida         3296.0
# 4    New York         3494.0
